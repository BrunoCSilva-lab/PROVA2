# %%
import random
def calcular_media(valores):
    if len(valores) == 0:
        return 0
    return sum(consumo_diario) / len(consumo_diario)
consumo_diario = [random.randint(1, 100) for _ in range(30)]
media = calcular_media(consumo_diario)
print("Lista de registros de consumo diário:", consumo_diario)
print("O consumo diário médio foi:", media)
# Out:
# Lista de registros de consumo diário: [23, 81, 11, 62, 44, 10, 14, 91, 56, 27, 46, 69, 27, 52, 87, 13, 20, 87, 60, 71, 34, 10, 27, 8, 77, 33, 83, 16, 82, 85]
# O consumo diário médio foi: 46.86666666666667
